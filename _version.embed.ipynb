# %% [markdown]
# #
#
# [Emmanuel BRUNO](https://bruno.univ-tln.fr) (Université de Toulon, LIS
# UMR CNRS 7020)
# 2025-02-24
#
# <table class="table-striped table-hover table-bordered">
# <colgroup>
# <col style="width: 14%" />
# <col style="width: 85%" />
# </colgroup>
# <tbody>
# <tr>
# <td>Source</td>
# <td><ul>
# <li><a
# href="https://github.com/ebpro/notebook-java-restfulws">https://github.com/ebpro/notebook-java-restfulws</a></li>
# </ul></td>
# </tr>
# <tr>
# <td>Branch</td>
# <td><ul>
# <li>develop (b798c84)</li>
# <li>2024/10/03 15:16:24</li>
# </ul></td>
# </tr>
# <tr>
# <td>Java</td>
# <td><ul>
# <li>OpenJDK Temurin-21.0.6+7</li>
# <li>Apache Maven 3.9.9</li>
# </ul></td>
# </tr>
# <tr>
# <td>Docker</td>
# <td><ul>
# <li>Client: 28.0.0 - buildx 7c2359c - compose v2.33.1 - scout
# v1.16.3</li>
# <li>Server: 27.5.1</li>
# </ul></td>
# </tr>
# </tbody>
# </table>
